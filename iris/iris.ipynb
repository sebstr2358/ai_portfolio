# %% [markdown]
# # Zadanie domowe - EDA Danych dotyczących Irysów
#
# * Twoim zadaniem jest wykonanie analizy danych zawartych w załączonym pliku CSV (`25__iris.csv`).
# * Plik znajduje się pod video. Pamiętaj, żeby wrzucić plik do tego samego folderu, w którym znajduje się ten notebook.
# * Wykorzystaj nowo nabytą wiedzę z biblioteki `Pandas`
# * Jeżeli jest taka konieczność posiłkuj się [code explainerem](https://codeexplainer.imprv.ai/) lub / i [data chatterem](https://datachatter.imprv.ai/) (który również te dane ma dostępne).
# * Prześlij na discordzie notebook z rozwiązaniem (`#modul-4-zad1`)
# * Pamiętaj:
#
# 1. Nie spiesz się
# 2. Potraktuj zadanie domowe jak prawdziwy projekt
# 3. Dodawaj opisy, obserwacje, wnioski
# 4. Dodaj wizualizacje
# 5. Dodaj konkluzję i wnioski końcowe
#
# Powodzenia!!! I mega zabawy!

# %% [markdown]
# ## O Danych
#
# Zbiór danych zawiera informacje o trzech gatunkach irysów: Iris setosa, Iris versicolor, i Iris virginica.
#
# Dane obejmują pomiary czterech cech: długość i szerokość działki kielicha oraz długość i szerokość płatka.
#
# Każdy wiersz w zbiorze danych reprezentuje pojedynczy kwiat, a wartości pomiarów są podane w centymetrach.
#
# Zbiór składa się z 150 próbek, po 50 dla każdego gatunku, i jest szeroko stosowany jako podstawowy zbiór danych do
# testowania algorytmów klasyfikacji oraz w nauce o danych i uczeniu maszynowym.
#
# Kolumny:
# * **długość kielicha (sepal length)** - Długość kielicha w cm
# * **szerokość kielicha (sepal width)** - Szerokość kielicha w cm
# * **długość płatka (petal length)** - Długość płatka w cm
# * **szerokość płatka (petal width)** - Szerokość płatka w cm
# * **klasa (class)** - Klasa irysa (setosa, versicolor, virginica)

# %% [markdown]
# # EDA - ANALIZA EKSPLORACYJNA DANYCH
# Analiza dotyczy irysów, czyli roślin z rodziny kosaćcowatych. Występują one w co najmniej 311 gatunkach. Cenione są z powodu efektownych i bardzo zróżnicowanych pod względem formy i barwy kwiatów. Bardzo liczne gatunki, mieszańce i odmiany uprawiane są jako rośliny ozdobne. Poniżej przeanalizowano rozmiary 3 gatunków irysów:
#
# - Iris setosa
# - Iris versicolor
# - Iris virginica

# %%
# import bibliotek pythona
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# zapewnienie wyświetlania każdej kolumny tabeli
pd.set_option('display.max_columns', None)

# %%
# załadowanie danych z pliku csv
df = pd.read_csv('25__iris.csv', sep=",")
df
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 0                                5.1                               3.5
# 1                                4.9                               3.0
# 2                                4.7                               3.2
# 3                                4.6                               3.1
# 4                                5.0                               3.6
# ..                               ...                               ...
# 145                              6.7                               3.0
# 146                              6.3                               2.5
# 147                              6.5                               3.0
# 148                              6.2                               3.4
# 149                              5.9                               3.0
#
#      długość płatka (petal length)  szerokość płatka (petal width)  \
# ...

# %% [markdown]
# ## 1. Ogólny przegląd danych
# ### 1.1. Analiza wstępna

# %%
# wyświetlenie 10 losowych rekordów
df.sample(10)
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 139                              6.9                               3.1
# 29                               4.7                               3.2
# 25                               5.0                               3.0
# 102                              7.1                               3.0
# 97                               6.2                               2.9
# 48                               5.3                               3.7
# 71                               6.1                               2.8
# 110                              6.5                               3.2
# 60                               5.0                               2.0
# 118                              7.7                               2.6
#
#      długość płatka (petal length)  szerokość płatka (petal width)  \
# 139                            5.4                             2.1
# ...

# %%
# ponowne wyświetlenie 10 losowych rekordów
df.sample(10)
# Out:
#      długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# 27                               5.2                               3.5
# 31                               5.4                               3.4
# 99                               5.7                               2.8
# 134                              6.1                               2.6
# 95                               5.7                               3.0
# 126                              6.2                               2.8
# 141                              6.9                               3.1
# 67                               5.8                               2.7
# 142                              5.8                               2.7
# 59                               5.2                               2.7
#
#      długość płatka (petal length)  szerokość płatka (petal width)  \
# 27                             1.5                             0.2
# ...

# %%
# sprawdzenie typów danych w poszczególnych kolumnach
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   długość kielicha (sepal length)   150 non-null    float64
#  1   szerokość kielicha (sepal width)  150 non-null    float64
#  2   długość płatka (petal length)     150 non-null    float64
#  3   szerokość płatka (petal width)    150 non-null    float64
#  4   klasa (class)                     150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# sprawdzenie ilości wartości unikalnych w poszczególnych kolumnach
df.nunique()
# Out:
# długość kielicha (sepal length)     35
# szerokość kielicha (sepal width)    23
# długość płatka (petal length)       43
# szerokość płatka (petal width)      22
# klasa (class)                        3
# dtype: int64

# %%
# obliczenie ilości rekordów dla każdej klasy
df['klasa (class)'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: klasa (class), dtype: int64

# %%
# obliczenie podstawowych statystyk dla każdej kolumny
df.describe()
# Out:
#        długość kielicha (sepal length)  szerokość kielicha (sepal width)  \
# count                       150.000000                        150.000000
# mean                          5.843333                          3.054000
# std                           0.828066                          0.433594
# min                           4.300000                          2.000000
# 25%                           5.100000                          2.800000
# 50%                           5.800000                          3.000000
# 75%                           6.400000                          3.300000
# max                           7.900000                          4.400000
#
#        długość płatka (petal length)  szerokość płatka (petal width)
# count                     150.000000                      150.000000
# mean                        3.758667                        1.198667
# std                         1.764420                        0.763161
# ...

# %% [markdown]
# ### 1.2. Spostrzeżenia i wnioski wstępne
# Dane zawierają 150 wierszów - równo po 50 dla każdej z 3 klas. Występępują 4 kolumny z wartościami liczbowymi (typ float). Na podstawie wstępnych statystyk dla ww. kolumn, największe zróżnicowanie danych (największa wartość odchylenia standardowego) można zauważyć w długości płatka, a najmniejsze w szerokości kielicha.

# %% [markdown]
# ## 2. Brakujące wartości
# ### 2.1. Analiza

# %%
# sprawdzenie ilości brakujących wartości w każdej kolumnie
df.isnull().sum()
# Out:
# długość kielicha (sepal length)     0
# szerokość kielicha (sepal width)    0
# długość płatka (petal length)       0
# szerokość płatka (petal width)      0
# klasa (class)                       0
# dtype: int64

# %% [markdown]
# ### 2.2. Spostrzeżenia i wnioski
# W danych nie ma braków, czyli każda kolumna zawiera 150 wartości.

# %% [markdown]
# ## 3. Badanie pojedynczych kolumn

# %%
# zmiana nazw i kolejności kolumn dla lepszej czytelności
df_all = df.rename(columns={'długość kielicha (sepal length)': 'długość kielicha', 'szerokość kielicha (sepal width)': 'szerokość kielicha', 'długość płatka (petal length)': 'długość płatka', 'szerokość płatka (petal width)': 'szerokość płatka', 'klasa (class)': 'klasa'})
df_all = df_all[['klasa', 'długość kielicha', 'szerokość kielicha', 'długość płatka', 'szerokość płatka']]
df_all
# Out:
#               klasa  długość kielicha  szerokość kielicha  długość płatka  \
# 0       Iris-setosa               5.1                 3.5             1.4
# 1       Iris-setosa               4.9                 3.0             1.4
# 2       Iris-setosa               4.7                 3.2             1.3
# 3       Iris-setosa               4.6                 3.1             1.5
# 4       Iris-setosa               5.0                 3.6             1.4
# ..              ...               ...                 ...             ...
# 145  Iris-virginica               6.7                 3.0             5.2
# 146  Iris-virginica               6.3                 2.5             5.0
# 147  Iris-virginica               6.5                 3.0             5.2
# 148  Iris-virginica               6.2                 3.4             5.4
# 149  Iris-virginica               5.9                 3.0             5.1
#
#      szerokość płatka
# 0                 0.2
# 1                 0.2
# ...

# %% [markdown]
# ### 3.1. Analiza bez podziału na klasy

# %%
# stworzenie przestrzeni na histogramy dla wszystkich kolumn numerycznych
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()

# stworzenie listy kolumn numerycznych
numerical_columns = ['długość kielicha', 'szerokość kielicha', 
                     'długość płatka', 'szerokość płatka']

# iterujemy po liście kolumn numerycznych i dla każdej generujemy histogram z KDE
for i, col in enumerate(numerical_columns):
    sns.histplot(df_all[col], kde=True, ax=axes[i])
    axes[i].set_title(numerical_columns[i].title())
    axes[i].set_xlabel(numerical_columns[i]+' [cm]')
    axes[i].set_ylabel('liczba wystąpień')

# dostosowujemy połozenie automatycznie
plt.tight_layout()

# %% [markdown]
# ### 3.2. Analiza z rozróżnieniem poszczególnych klas

# %%
# stworzenie przestrzeni dla 4 histogramów
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()

# stworzenie listy kolumn numerycznych
features = ['długość kielicha', 'szerokość kielicha', 'długość płatka', 'szerokość płatka']

# iterujemy po każdej klasie w każdej kolumnie numerycznej i tworzymy 4 histogramy
for i, feature in enumerate(features):
    for class_name, group in df_all.groupby('klasa'):
        axes[i].hist(group[feature], bins=10, alpha=0.5, label=class_name)
        axes[i].set_title(feature.title())
        axes[i].set_xlabel(feature)
        axes[i].set_ylabel('liczba wystąpień')
        axes[i].legend()

# ustawiamy automatyczne dostosowanie
plt.tight_layout()

# %%
# obliczamy średnią atyrmetyczną dla kolumn numerycznych w poszczególnych klasach
df_class_mean = df_all.groupby('klasa').mean()
df_class_mean
# Out:
#                  długość kielicha  szerokość kielicha  długość płatka  \
# klasa
# Iris-setosa                 5.006               3.418           1.464
# Iris-versicolor             5.936               2.770           4.260
# Iris-virginica              6.588               2.974           5.552
#
#                  szerokość płatka
# klasa
# Iris-setosa                 0.244
# Iris-versicolor             1.326
# Iris-virginica              2.026

# %%
# tworzymy przestrzeń dla wykresów średnich wartości kolumn numerycznych z podziałem na klasy
fix, axes = plt.subplots(2, 2, figsize=(12,8))
axes[0, 0].bar(df_class_mean.index, df_class_mean['długość kielicha'])
axes[0, 0].set_title('Średnia wartość długości kielicha')
axes[0, 0].set_xlabel('klasa')
axes[0, 0].set_ylabel('ługość')

axes[0, 1].bar(df_class_mean.index, df_class_mean['szerokość kielicha'])
axes[0, 1].set_title('Średnia wartość szerokości kielicha')
axes[0, 1].set_xlabel('klasa')
axes[0, 1].set_ylabel('szerokość')

axes[1, 0].bar(df_class_mean.index, df_class_mean['długość płatka'])
axes[1, 0].set_title('Średnia wartość długości płatka')
axes[1, 0].set_xlabel('klasa')
axes[1, 0].set_ylabel('długość')

axes[1, 1].bar(df_class_mean.index, df_class_mean['szerokość płatka'])
axes[1, 1].set_title('Średnia wartość szerokości płatka')
axes[1, 1].set_xlabel('klasa')
axes[1, 1].set_ylabel('szerokość')

plt.tight_layout()
plt.savefig('average_std_values_barChart')

# %%
# tworzymy wykres przedstawiający klasy wraz ze średnimi wartościami kolumn numerycznych osiąganych w tych klasach
df_all.groupby('klasa', as_index=False).mean().plot(kind='bar', x='klasa', y=['długość kielicha', 'szerokość kielicha', 'długość płatka', 'szerokość płatka'])

plt.xticks(rotation=0)

plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left')

# %% [markdown]
# ### 3.3. Spostrzeżenia i wnioski
# Analizując wartości pojedynczych kolumn, bez podziału na klasy, można zauważyć rozkład zbliżony do rozkładu normalnego (krzywek Gaussa) jedynie dla szerokości kielicha. Długość i szerokość płatka mają natomiast rozkład przemienny - przypominający sinusoidę.
# Rozpatrując poszczególne klasy, można dostrzec wyraźne zróżnicowanie. Największe wymiary kielicha i płatka ma gatunek Iris-virginica z wyjątkiem szerokości kielicha - tu największa średnia wartość przypada dla Iris-setosa. W pozostałych trzech cechach Iris-setosa przyjmuje wartości najmniejsze.

# %% [markdown]
# ## 4. Transformacja danych

# %% [markdown]
# ### 4.1. Sprawdzenie istnienia duplikatów

# %%
# sprawdzamy istnienie duplikatów
df_all[df_all.duplicated()]
# Out:
#               klasa  długość kielicha  szerokość kielicha  długość płatka  \
# 34      Iris-setosa               4.9                 3.1             1.5
# 37      Iris-setosa               4.9                 3.1             1.5
# 142  Iris-virginica               5.8                 2.7             5.1
#
#      szerokość płatka
# 34                0.1
# 37                0.1
# 142               1.9

# %% [markdown]
# ### 4.2. Wnioski
# W rozpatrywanych danych duplikaty występują. Fizycznie mogą istnieć 2 lub więcej irysy o identycznych wymiarach kielicha i płatka, więc nie ma podstaw, aby traktować to jako błąd pomiarowy. Duplikaty nie zostaną usunięte.

# %% [markdown]
# ## 5. Analiza relacji między zmiennymi
# ### 5.1. Macierz korelacji bez podziału na klasy

# %%
# stworzenie macierzy korelacji między cechami
plt.figure(figsize=(7,5))
sns.heatmap(df_all.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Macierz korelacji')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15560\1458630475.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_all.corr(), annot=True, cmap='coolwarm', fmt='.2f')
# Text(0.5, 1.0, 'Macierz korelacji')

# %% [markdown]
# ### 5.2. Macierz korelacji dla poszczególnych klas

# %%
## stworzenie macierzy korelacji między cechami dla każdej klasy oddzielnie
# Iterujemy po każdej z 3 klas
for iris_class in df_all['klasa'].unique():
    # filtrujemy dane po klasie
    df_class = df_all[df_all['klasa'] == iris_class]
    
    # tworzymy zmienną, do której przypisujemy macierz korelacji dla wszystkich kolumn numerycznych
    corr = df_class.drop(columns='klasa').corr()
    
    # rysujemy macierze korelacji
    plt.figure(figsize=(7, 5))
    sns.heatmap(corr, annot=True, cmap='coolwarm', cbar=True)
    plt.title(f'Macierz korelacji dla {iris_class}')

# %% [markdown]
# ### 5.3. Wnioski
# W ogólnej macierzy korelacji (bez podziału na klasy) możemy dostrzec wyraźną korelację między długością płatka i szerokością płatka oraz między długością płatka i długością kielicha. Gdy spojrzymy na macierze korelacji poszczególych klas to pierwszy z ww. trendów powtarza się jedynie w klasie Iris-versicolor, a drugi w klasach Iris-versicolor i Iris-virginica.
# Ponadto, w klasie Iris-setosa można zauważyć wyraźną korelację między długością i szerokością kielicha.

# %% [markdown]
# ### 5.4. Wykresy punktowe dla wszystkich kolumn z podziałem na klasy

# %%
# rysujemy pairploty dla wszystkich kolumn z podziałem na klasy
pairplot = sns.pairplot(df_all, hue='klasa', kind = 'reg')

# %%
# rysujemy pairplot kolumn numerycznych dla klasy Iris-setosa
pairplot = sns.pairplot(df_all[df_all['klasa'] == 'Iris-setosa'],  kind='reg')

# %%
# rysujemy pairplot kolumn numerycznych dla klasy Iris-versicolor
pairplot = sns.pairplot(df_all[df_all['klasa'] == 'Iris-versicolor'],  kind='reg')

# %%
# rysujemy pairplot kolumn numerycznych dla klasy Iris-virginica
pairplot = sns.pairplot(df_all[df_all['klasa'] == 'Iris-virginica'],  kind='reg')

# %% [markdown]
# ## 6. Analiza wartości odstających
# ### 6.1. Wykresy pudełkowe (boxploty)

# %%
# Rysujemy boxploty dla każdej kolumny numerycznej, aby znaleźć wartości odstające
plt.figure(figsize=(7, 5))
df_all.select_dtypes(include='number').boxplot(vert=False)

# instrukcje dotyczące podpisu osi X
plt.xlabel('Wartości [cm]')


#tytuł wykresu
plt.title('Boxplot kolumn numerycznych')
# Out:
# Text(0.5, 1.0, 'Boxplot kolumn numerycznych')

# %%
# Rysowanie barplotów szerokości kielicha dla każdej klasy
plt.figure(figsize=(8, 6))
sns.boxplot(x='klasa', y='szerokość kielicha', data=df_all)

# tytuł
plt.title('Boxplot szerokości kielicha dla poszczególnych klas')

# instrukcje dotyczące rozmieszczenia indformacji na osiach X i Y
plt.xlabel('klasa')
plt.ylabel('szerokość kielicha [cm]')
# Out:
# Text(0, 0.5, 'szerokość kielicha [cm]')

# %% [markdown]
# ### 6.2. Spostrzeżenia i wnioski
# Na boxplocie dla wszystkich kolumn numerycznych, bez podziału na klasy, można zauważyć wartości odstające jedynie dla cechy szerokość kielicha. Gdy zbadamy tę cechę z rozbiciem na poszczególne klasy to można dostrzec, że wartości odstające pojawiają się jedynie w klasie Iris-virginica. Może to świadczyć o wystąpieniu błędu pomiarowego lub o szerokim zakresie wartości, który szerokość kielicha może przyjmować.
